# %%
pip install quandl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl
import pandas as pd
import os
import random

# %%
quandl.ApiConfig.api_key = 'qoZr9QNEwYKyHJymGzEg'

# %%
Bitcoin_my_wallet_num_users = quandl.get("BCHAIN/MWNUS")
Bitcoin_my_wallet_num_users['Date'] = Bitcoin_my_wallet_num_users.index

Volume = quandl.get('BCHAIN/TRVOU')
Volume['Date']= Volume.index

Difficulty = quandl.get('BCHAIN/DIFF')
Difficulty['Date'] = Difficulty.index

wallet_num_transaction = quandl.get('BCHAIN/MWNTD')
wallet_num_transaction['Date'] = wallet_num_transaction.index

wallet_transaction_volume = quandl.get('BCHAIN/MWTRV')
wallet_transaction_volume['Date'] = wallet_transaction_volume.index

Bitcoin_Avg_Block_Size = quandl.get('BCHAIN/AVBLS')
Bitcoin_Avg_Block_Size['Date'] = Bitcoin_Avg_Block_Size.index

Miners_Revenue = quandl.get('BCHAIN/MIREV')
Miners_Revenue['Date'] = Miners_Revenue.index

Hash_Rate = quandl.get('BCHAIN/HRATE')
Hash_Rate['Date'] = Hash_Rate.index

Bitcoin_Cost_Transaction = quandl.get('BCHAIN/CPTRA')
Bitcoin_Cost_Transaction['Date'] = Bitcoin_Cost_Transaction.index

Bitcoin_Cost_percentage_of_Transaction_Volume = quandl.get('BCHAIN/CPTRV')
Bitcoin_Cost_percentage_of_Transaction_Volume['Date'] = Bitcoin_Cost_percentage_of_Transaction_Volume.index

Estimated_Transaction_Volume = quandl.get('BCHAIN/ETRAV')
Estimated_Transaction_Volume['Date'] = Estimated_Transaction_Volume.index

Total_Output_Volume = quandl.get('BCHAIN/TOUTV')
Total_Output_Volume['Date'] = Total_Output_Volume.index

num_transaction_per_Block = quandl.get('BCHAIN/NTRBL')
num_transaction_per_Block['Date'] = num_transaction_per_Block.index

num_of_unique_addresses = quandl.get('BCHAIN/NADDU')
num_of_unique_addresses['Date'] = num_of_unique_addresses.index

num_of_transaction = quandl.get('BCHAIN/NTRAN')
num_of_transaction['Date'] = num_of_transaction.index

Total_transaction_fees = quandl.get('BCHAIN/TRFEE')
Total_transaction_fees['Date'] = Total_transaction_fees.index

Total_Bitcoins = quandl.get('BCHAIN/TOTBC')
Total_Bitcoins['Date'] = Total_Bitcoins.index

Median_transaction_confirmation_time = quandl.get('BCHAIN/ATRCT')
Median_transaction_confirmation_time['Date'] = Median_transaction_confirmation_time.index

# %%
Date_vec = []
for i in Bitcoin_my_wallet_num_users['Date']:
    for j in Volume['Date']:
        if i == j:
            Date_vec.append(i)

# %%
Date_vec2 = []
for i in Date_vec:
    for j in Difficulty['Date']:
        if i == j:
            Date_vec2.append(i)

# %%
Date_vec3 = []
for i in Date_vec2:
    for j in wallet_num_transaction['Date']:
        if i == j:
            Date_vec3.append(i)
Date_vec4 = []
for i in Date_vec3:
    for j in wallet_transaction_volume['Date']:
        if i == j:
            Date_vec4.append(i)

# %%
Date_vec5 = []
for i in Date_vec4:
    for j in Bitcoin_Avg_Block_Size['Date']:
        if i == j:
            Date_vec5.append(i)
Date_vec6 = []
for i in Date_vec5:
    for j in Miners_Revenue['Date']:
        if i == j:
            Date_vec6.append(i)

# %%
Date_vec7 = []
for i in Date_vec6:
    for j in Hash_Rate['Date']:
        if i == j:
            Date_vec7.append(i)
            
Date_vec8 = []
for i in Date_vec7:
    for j in Bitcoin_Cost_Transaction['Date']:
        if i == j:
            Date_vec8.append(i)

# %%
Date_vec9 = []
for i in Date_vec8:
    for j in Bitcoin_Cost_percentage_of_Transaction_Volume['Date']:
        if i == j:
            Date_vec9.append(i)
Date_vec10 = []
for i in Date_vec9:
    for j in Estimated_Transaction_Volume['Date']:
        if i == j:
            Date_vec10.append(i)
Date_vec11 = []
for i in Date_vec10:
    for j in Total_Output_Volume['Date']:
        if i == j:
            Date_vec11.append(i)

# %%
Date_vec12 = []
for i in Date_vec11:
    for j in num_transaction_per_Block['Date']:
        if i == j:
            Date_vec12.append(i)
Date_vec13 = []
for i in Date_vec12:
    for j in num_of_unique_addresses['Date']:
        if i == j:
            Date_vec13.append(i)
Date_vec14 = []
for i in Date_vec13:
    for j in num_of_transaction['Date']:
        if i == j:
            Date_vec14.append(i)

# %%
Date_vec15 = []
for i in Date_vec14:
    for j in Total_transaction_fees['Date']:
        if i == j:
            Date_vec15.append(i)
Date_vec16 = []
for i in Date_vec15:
    for j in Total_Bitcoins['Date']:
        if i == j:
            Date_vec16.append(i)

Date_vec17 = []
for i in Date_vec16:
    for j in Median_transaction_confirmation_time['Date']:
        if i == j:
            Date_vec17.append(i)

# %%
#### Mergning Data
Data_Collection = pd.DataFrame()
Data_Collection['Bitcoin_my_wallet_num_users'] = Bitcoin_my_wallet_num_users.loc[Date_vec17,'Value']
Data_Collection['Volume'] = Volume.loc[Date_vec17, 'Value']
Data_Collection['Difficulty'] = Difficulty.loc[Date_vec17, 'Value']
Data_Collection['wallet_num_transaction'] = wallet_num_transaction.loc[Date_vec17, 'Value']
Data_Collection ['wallet_transaction_volume']= wallet_transaction_volume.loc[Date_vec17, 'Value']
Data_Collection['Bitcoin_Avg_Block_Size'] = Bitcoin_Avg_Block_Size.loc[Date_vec17, 'Value']
Data_Collection['Miners_Revenue'] = Miners_Revenue.loc[Date_vec17, 'Value']
Data_Collection['Hash_Rate'] = Hash_Rate.loc[Date_vec17, 'Value']
Data_Collection['Bitcoin_Cost_Transaction'] = Bitcoin_Cost_Transaction.loc[Date_vec17, 'Value']
Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] = Bitcoin_Cost_percentage_of_Transaction_Volume.loc[Date_vec17, 'Value']
Data_Collection['Estimated_Transaction_Volume'] = Estimated_Transaction_Volume.loc[Date_vec17, 'Value']
Data_Collection['Total_Output_Volume'] = Total_Output_Volume.loc[Date_vec17, 'Value']
Data_Collection['num_transaction_per_Block'] = num_transaction_per_Block.loc[Date_vec17, 'Value']
Data_Collection['num_of_unique_addresses'] = num_of_unique_addresses.loc[Date_vec17, 'Value']
Data_Collection ['num_of_transaction'] = num_of_transaction.loc[Date_vec17, 'Value'] 
Data_Collection['Total_transaction_fees'] = Total_transaction_fees.loc[Date_vec17, 'Value']
Data_Collection['Total_Bitcoins']= Total_Bitcoins.loc[Date_vec17, 'Value']
Data_Collection['Median_transaction_confirmation_time'] = Median_transaction_confirmation_time.loc[Date_vec17, 'Value']

# %%
New_Data_Collection1 = Data_Collection.iloc[1145 : , :]
del New_Data_Collection1['wallet_transaction_volume']
Final_Data_Collection = New_Data_Collection1.fillna(method = 'ffill')
Final_Data_Collection = New_Data_Collection1.dropna()
Final_Data_Collection.isnull().sum()
# Out:
# Bitcoin_my_wallet_num_users                      0
# Volume                                           0
# Difficulty                                       0
# wallet_num_transaction                           0
# Bitcoin_Avg_Block_Size                           0
# Miners_Revenue                                   0
# Hash_Rate                                        0
# Bitcoin_Cost_Transaction                         0
# Bitcoin_Cost_percentage_of_Transaction_Volume    0
# Estimated_Transaction_Volume                     0
# Total_Output_Volume                              0
# num_transaction_per_Block                        0
# num_of_unique_addresses                          0
# num_of_transaction                               0
# Total_transaction_fees                           0
# Total_Bitcoins                                   0
# Median_transaction_confirmation_time             0
# dtype: int64

# %%
volume_vec = []
j = 0
for i in Final_Data_Collection['Volume']:
    if i == 0:
        a = (Final_Data_Collection['Volume'][j-1] + Final_Data_Collection['Volume'][j+1]) / 2
        volume_vec.append(a)
    else:
        volume_vec.append(i)
    j = j + 1
    
Final_Data_Collection['Volume'] = volume_vec

#2.
wallet_num_trans_vec = []
j = 0
for i in Final_Data_Collection['wallet_num_transaction']:
    if i == 0:
        a = (Final_Data_Collection['wallet_num_transaction'][j - 1] + Final_Data_Collection['wallet_num_transaction'][j + 1]) / 2
        wallet_num_trans_vec.append(a)
    else:
        wallet_num_trans_vec.append(i)
    j = j + 1
    

Final_Data_Collection['wallet_num_transaction'] = wallet_num_trans_vec

Final_Data_Collection['Bitcoin_my_wallet_num_users_2'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] * Final_Data_Collection['Bitcoin_my_wallet_num_users']
Final_Data_Collection['Volume_2'] = Final_Data_Collection['Volume'] * Final_Data_Collection['Volume']
Final_Data_Collection['Difficulty_2'] =Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty']
Final_Data_Collection['wallet_num_transaction_2'] = Final_Data_Collection['wallet_num_transaction'] * Final_Data_Collection['wallet_num_transaction']
Final_Data_Collection['Bitcoin_Avg_Block_Size_2'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] * Final_Data_Collection['Bitcoin_Avg_Block_Size']
Final_Data_Collection['Miners_Revenue_2'] = Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue']
Final_Data_Collection['Hash_Rate_2'] = Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate']
Final_Data_Collection['Bitcoin_Cost_Transaction_2'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction']
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_2'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume']
Final_Data_Collection['Estimated_Transaction_Volume_2'] = Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume']
Final_Data_Collection['Total_Output_Volume_2'] = Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume']
Final_Data_Collection['num_transaction_per_Block_2'] = Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block']
Final_Data_Collection['num_of_unique_addresses_2'] = Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses']
Final_Data_Collection['num_of_transaction_2'] = Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction']
Final_Data_Collection['Total_transaction_fees_2'] = Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees']
Final_Data_Collection['Total_Bitcoins_2'] = Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins']
Final_Data_Collection['Median_transaction_confirmation_time_2'] = Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time']

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_3'] = Final_Data_Collection['Bitcoin_my_wallet_num_users']* Final_Data_Collection['Bitcoin_my_wallet_num_users'] * Final_Data_Collection['Bitcoin_my_wallet_num_users']
Final_Data_Collection['Volume_3'] = Final_Data_Collection['Volume'] * Final_Data_Collection['Volume'] * Final_Data_Collection['Volume']
Final_Data_Collection['Difficulty_3'] =Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty']
Final_Data_Collection['wallet_num_transaction_3'] = Final_Data_Collection['wallet_num_transaction']*Final_Data_Collection['wallet_num_transaction'] * Final_Data_Collection['wallet_num_transaction']
Final_Data_Collection['Bitcoin_Avg_Block_Size_3'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] *Final_Data_Collection['Bitcoin_Avg_Block_Size'] * Final_Data_Collection['Bitcoin_Avg_Block_Size']
Final_Data_Collection['Miners_Revenue_3'] = Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue']
Final_Data_Collection['Hash_Rate_3'] = Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate']
Final_Data_Collection['Bitcoin_Cost_Transaction_3'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction']
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_3'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume']
Final_Data_Collection['Estimated_Transaction_Volume_3'] = Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume']
Final_Data_Collection['Total_Output_Volume_3'] = Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume']
Final_Data_Collection['num_transaction_per_Block_3'] = Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block']
Final_Data_Collection['num_of_unique_addresses_3'] = Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses']
Final_Data_Collection['num_of_transaction_3'] = Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction']
Final_Data_Collection['Total_transaction_fees_3'] = Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees']
Final_Data_Collection['Total_Bitcoins_3'] = Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins']
Final_Data_Collection['Median_transaction_confirmation_time_3'] = Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time']

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_4'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] ** 4
Final_Data_Collection['Volume_4'] = Final_Data_Collection['Volume'] ** 4
Final_Data_Collection['Difficulty_4'] =Final_Data_Collection['Difficulty'] ** 4
Final_Data_Collection['wallet_num_transaction_4'] = Final_Data_Collection['wallet_num_transaction'] ** 4
Final_Data_Collection['Bitcoin_Avg_Block_Size_4'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] ** 4
Final_Data_Collection['Miners_Revenue_4'] = Final_Data_Collection['Miners_Revenue'] ** 4
Final_Data_Collection['Hash_Rate_4'] = Final_Data_Collection['Hash_Rate'] ** 4
Final_Data_Collection['Bitcoin_Cost_Transaction_4'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] ** 4
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_4'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] ** 4
Final_Data_Collection['Estimated_Transaction_Volume_4'] = Final_Data_Collection['Estimated_Transaction_Volume'] ** 4
Final_Data_Collection['Total_Output_Volume_4'] = Final_Data_Collection['Total_Output_Volume'] ** 4
Final_Data_Collection['num_transaction_per_Block_4'] = Final_Data_Collection['num_transaction_per_Block'] ** 4
Final_Data_Collection['num_of_unique_addresses_4'] = Final_Data_Collection['num_of_unique_addresses'] ** 4
Final_Data_Collection['num_of_transaction_4'] = Final_Data_Collection['num_of_transaction'] ** 4
Final_Data_Collection['Total_transaction_fees_4'] = Final_Data_Collection['Total_transaction_fees'] ** 4
Final_Data_Collection['Total_Bitcoins_4'] = Final_Data_Collection['Total_Bitcoins'] ** 4
Final_Data_Collection['Median_transaction_confirmation_time_4'] = Final_Data_Collection['Median_transaction_confirmation_time'] ** 4

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_5'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] ** 5
Final_Data_Collection['Volume_5'] = Final_Data_Collection['Volume'] ** 5
Final_Data_Collection['Difficulty_5'] =Final_Data_Collection['Difficulty'] ** 5
Final_Data_Collection['wallet_num_transaction_5'] = Final_Data_Collection['wallet_num_transaction'] ** 5
Final_Data_Collection['Bitcoin_Avg_Block_Size_5'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] ** 5
Final_Data_Collection['Miners_Revenue_5'] = Final_Data_Collection['Miners_Revenue'] ** 5
Final_Data_Collection['Hash_Rate_5'] = Final_Data_Collection['Hash_Rate'] ** 5
Final_Data_Collection['Bitcoin_Cost_Transaction_5'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] ** 5
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_5'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] ** 4
Final_Data_Collection['Estimated_Transaction_Volume_5'] = Final_Data_Collection['Estimated_Transaction_Volume'] ** 5
Final_Data_Collection['Total_Output_Volume_5'] = Final_Data_Collection['Total_Output_Volume'] ** 5
Final_Data_Collection['num_transaction_per_Block_5'] = Final_Data_Collection['num_transaction_per_Block'] ** 5
Final_Data_Collection['num_of_unique_addresses_5'] = Final_Data_Collection['num_of_unique_addresses'] ** 5
Final_Data_Collection['num_of_transaction_5'] = Final_Data_Collection['num_of_transaction'] ** 5
Final_Data_Collection['Total_transaction_fees_5'] = Final_Data_Collection['Total_transaction_fees'] ** 5
Final_Data_Collection['Total_Bitcoins_5'] = Final_Data_Collection['Total_Bitcoins'] ** 5
Final_Data_Collection['Median_transaction_confirmation_time_5'] = Final_Data_Collection['Median_transaction_confirmation_time'] ** 5

# %%
del Final_Data_Collection['Class']

# %%
###### Start collecting Y (Bitcoin Price) BCHAIN/MKPRU
Bitcoin_Price = quandl.get('BCHAIN/MKPRU')
Bitcoin_Price['Date'] = Bitcoin_Price.index
New_Date_Table = pd.DataFrame()
New_Date_Table['Date'] = Final_Data_Collection.index
Date_vec18 = []
for i in New_Date_Table['Date']:
    for j in Bitcoin_Price['Date']:
        if i == j:
            Date_vec18.append(i)

# %%
with open("Date_vec18.txt", "w") as output:
    output.write(str(Date_vec18))

# %%
Price_Table = pd.DataFrame()
Price_Table['Bitcoin_Price'] = Bitcoin_Price.loc[Date_vec18, 'Value']
Price_Table.shape
# Out:
# (2986, 1)

# %%
###### 2 classifiers

# %%
Price_Table['Growth'] = (Price_Table['Bitcoin_Price'].shift(-1) - Price_Table['Bitcoin_Price'])/Price_Table['Bitcoin_Price']

# %%
class_vec = [] #1 is good, 2 is ok, 3 is bad
for i in Price_Table['Growth']:
    if i >= 0.05:
        class_vec.append(1)
    elif i < 0:
        class_vec.append(3)
    else:
        class_vec.append(2)
Price_Table['Class'] = class_vec

# %%
Price_Table.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/Price_2Class.csv')

# %%
Final_Data_Collection['Class'] = Price_Table['Class']
Final_Data_Collection.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/FinalDataCollection_5.csv')

# %%
# Out:
# (2986, 52)

# %%
random_index = random.sample(range(0,len(Price_Table)),len(Price_Table))
Random_Data = pd.DataFrame()
Random_Data = Final_Data_Collection.iloc[random_index,:]
Random_Data.shape
# Out:
# (2986, 86)

# %%
#2090
#Train_Data
Train_Data = pd.DataFrame()
Train_Data = Random_Data.iloc[0:2100, :]
Train_Data.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/TrainData_5_2c.csv')
#Test_Data
Test_Data = pd.DataFrame()
Test_Data = Random_Data.iloc[2100:2530,:]
Test_Data.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/TestData_5_2c.csv')
#CV_Data
CV_Data = pd.DataFrame()
CV_Data = Random_Data.iloc[2530: , :]
CV_Data.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/CVData_5_2c.csv')

# %%
############################################# ADDING More Features ###############################################

# %%
#####Import New DATA
#Fed Long term real rates
LT_Rate = quandl.get('USTREASURY/REALLONGTERM', start_date='2012-02-22') #https://www.quandl.com/data/USTREASURY-US-Treasury
LT_Rate['Date'] = LT_Rate.index #LT Real Average (>10Yrs)	

#US AAA bond yield
AAA = quandl.get('ML/AAAEY', start_date='2012-02-22') #https://www.quandl.com/data/ML-Corporate-Bond-Yield-Rates
AAA['Date'] = AAA.index #BAMLC0A1CAAAEY

### Gold Price #https://www.quandl.com/data/LBMA-London-Bullion-Market-Association
Gold = quandl.get('LBMA/GOLD', start_date='2012-02-22') #USD(PM)
Gold['Date'] = Gold.index

### Crude Oil https://www.quandl.com/data/OPEC-Organization-of-the-Petroleum-Exporting-Countries
Oil = quandl.get('OPEC/ORB', start_date='2012-02-22')
Oil['Date'] = Oil.index
# Out:
#              Value       Date
# Date
# 2012-02-22  120.87 2012-02-22
# 2012-02-23  121.69 2012-02-23
# 2012-02-24  122.86 2012-02-24
# 2012-02-27  123.24 2012-02-27
# 2012-02-28  122.14 2012-02-28
# ...            ...        ...
# 2021-06-24   74.09 2021-06-24
# 2021-06-25   74.19 2021-06-25
# 2021-06-28   73.84 2021-06-28
# 2021-06-29   73.34 2021-06-29
# 2021-06-30   73.60 2021-06-30
#
# [2411 rows x 2 columns]

# %%
Bitcoin_Price = quandl.get('BCHAIN/MKPRU', start_date='2012-02-22' )
Bitcoin_Price['Date'] = Bitcoin_Price.index
Bitcoin_Price['Growth'] = (Bitcoin_Price['Value'].shift(-1) - Bitcoin_Price['Value']) / Bitcoin_Price['Value']
class_vec = [] #1 is good, 2 is ok, 3 is bad
for i in Bitcoin_Price['Growth']:
    if i >= 0:
        class_vec.append(1)
    else:
        class_vec.append(2)
Bitcoin_Price['Class'] = class_vec

# %%
Date_vec19 = [] #Old vs LT_Rate
for i in Date_vec17:
    for j in LT_Rate['Date']:
        if i == j:
            Date_vec19.append(i)

# %%
Date_vec20 = [] #Old + LT_Rate = 19 vs AAA
for i in Date_vec19:
    for j in AAA['Date']:
        if i == j:
            Date_vec20.append(i)

# %%
Date_vec21 = [] #Old + LT_Rate + AAA 20 vs Gold
for i in Date_vec20:
    for j in Gold['Date']:
        if i == j:
            Date_vec21.append(i)

# %%
Date_vec22 = [] #Old + LT_Rate + AAA + Gold 21 vs Oil
for i in Date_vec21:
    for j in Oil['Date']:
        if i == j:
            Date_vec22.append(i)

# %%
Date_vec23 = [] #All vs Y
for i in Date_vec22:
    for j in Bitcoin_Price['Date']:
        if i == j:
            Date_vec23.append(i)

# %%
Date_vec_F = Date_vec23

# %%
len(Date_vec_F)
# Out:
# 2010

# %%
#### Mergning OLD Data
Data_Collection = pd.DataFrame()
Data_Collection['Bitcoin_my_wallet_num_users'] = Bitcoin_my_wallet_num_users.loc[Date_vec_F,'Value']
Data_Collection['Volume'] = Volume.loc[Date_vec_F, 'Value']
Data_Collection['Difficulty'] = Difficulty.loc[Date_vec_F, 'Value']
Data_Collection['wallet_num_transaction'] = wallet_num_transaction.loc[Date_vec_F, 'Value']
Data_Collection ['wallet_transaction_volume']= wallet_transaction_volume.loc[Date_vec_F, 'Value']
Data_Collection['Bitcoin_Avg_Block_Size'] = Bitcoin_Avg_Block_Size.loc[Date_vec_F, 'Value']
Data_Collection['Miners_Revenue'] = Miners_Revenue.loc[Date_vec_F, 'Value']
Data_Collection['Hash_Rate'] = Hash_Rate.loc[Date_vec_F, 'Value']
Data_Collection['Bitcoin_Cost_Transaction'] = Bitcoin_Cost_Transaction.loc[Date_vec_F, 'Value']
Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] = Bitcoin_Cost_percentage_of_Transaction_Volume.loc[Date_vec_F, 'Value']
Data_Collection['Estimated_Transaction_Volume'] = Estimated_Transaction_Volume.loc[Date_vec_F, 'Value']
Data_Collection['Total_Output_Volume'] = Total_Output_Volume.loc[Date_vec_F, 'Value']
Data_Collection['num_transaction_per_Block'] = num_transaction_per_Block.loc[Date_vec_F, 'Value']
Data_Collection['num_of_unique_addresses'] = num_of_unique_addresses.loc[Date_vec_F, 'Value']
Data_Collection ['num_of_transaction'] = num_of_transaction.loc[Date_vec_F, 'Value'] 
Data_Collection['Total_transaction_fees'] = Total_transaction_fees.loc[Date_vec_F, 'Value']
Data_Collection['Total_Bitcoins']= Total_Bitcoins.loc[Date_vec_F, 'Value']
Data_Collection['Median_transaction_confirmation_time'] = Median_transaction_confirmation_time.loc[Date_vec_F, 'Value']

# %%
#### Merging New Data
Data_Collection['LT_Rate'] = LT_Rate.loc[Date_vec_F, 'LT Real Average (>10Yrs)']
Data_Collection['AAA'] = AAA.loc[Date_vec_F, 'BAMLC0A1CAAAEY']
Data_Collection['Gold'] = Gold.loc[Date_vec_F, 'USD (PM)']
Data_Collection['Oil'] = Oil.loc[Date_vec_F, 'Value']
Data_Collection['Class'] = Bitcoin_Price.loc[Date_vec_F,'Class']

# %%
del Data_Collection['wallet_transaction_volume']
Final_Data_Collection = Data_Collection.fillna(method = 'ffill')
Final_Data_Collection = Data_Collection.dropna()
Final_Data_Collection.isnull().sum()
# Out:
# Bitcoin_my_wallet_num_users                      0
# Volume                                           0
# Difficulty                                       0
# wallet_num_transaction                           0
# Bitcoin_Avg_Block_Size                           0
# Miners_Revenue                                   0
# Hash_Rate                                        0
# Bitcoin_Cost_Transaction                         0
# Bitcoin_Cost_percentage_of_Transaction_Volume    0
# Estimated_Transaction_Volume                     0
# Total_Output_Volume                              0
# num_transaction_per_Block                        0
# num_of_unique_addresses                          0
# num_of_transaction                               0
# Total_transaction_fees                           0
# Total_Bitcoins                                   0
# Median_transaction_confirmation_time             0
# LT_Rate                                          0
# ...

# %%
volume_vec = []
j = 0
for i in Final_Data_Collection['Volume']:
    if i == 0:
        a = (Final_Data_Collection['Volume'][j-1] + Final_Data_Collection['Volume'][j+1]) / 2
        volume_vec.append(a)
    else:
        volume_vec.append(i)
    j = j + 1
    
Final_Data_Collection['Volume'] = volume_vec

#2.
wallet_num_trans_vec = []
j = 0
for i in Final_Data_Collection['wallet_num_transaction']:
    if i == 0:
        a = (Final_Data_Collection['wallet_num_transaction'][j - 1] + Final_Data_Collection['wallet_num_transaction'][j + 1]) / 2
        wallet_num_trans_vec.append(a)
    else:
        wallet_num_trans_vec.append(i)
    j = j + 1
    

Final_Data_Collection['wallet_num_transaction'] = wallet_num_trans_vec
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
############# POLYNOMIAL

# %%
#2nd Power
del Final_Data_Collection['Class']

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_2'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] * Final_Data_Collection['Bitcoin_my_wallet_num_users']
Final_Data_Collection['Volume_2'] = Final_Data_Collection['Volume'] * Final_Data_Collection['Volume']
Final_Data_Collection['Difficulty_2'] =Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty']
Final_Data_Collection['wallet_num_transaction_2'] = Final_Data_Collection['wallet_num_transaction'] * Final_Data_Collection['wallet_num_transaction']
Final_Data_Collection['Bitcoin_Avg_Block_Size_2'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] * Final_Data_Collection['Bitcoin_Avg_Block_Size']
Final_Data_Collection['Miners_Revenue_2'] = Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue']
Final_Data_Collection['Hash_Rate_2'] = Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate']
Final_Data_Collection['Bitcoin_Cost_Transaction_2'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction']
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_2'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume']
Final_Data_Collection['Estimated_Transaction_Volume_2'] = Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume']
Final_Data_Collection['Total_Output_Volume_2'] = Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume']
Final_Data_Collection['num_transaction_per_Block_2'] = Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block']
Final_Data_Collection['num_of_unique_addresses_2'] = Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses']
Final_Data_Collection['num_of_transaction_2'] = Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction']
Final_Data_Collection['Total_transaction_fees_2'] = Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees']
Final_Data_Collection['Total_Bitcoins_2'] = Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins']
Final_Data_Collection['Median_transaction_confirmation_time_2'] = Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['LT_Rate_2'] = Final_Data_Collection['LT_Rate'] ** 2
Final_Data_Collection['AAA_2'] = Final_Data_Collection['AAA'] ** 2
Final_Data_Collection['Gold_2'] = Final_Data_Collection['Gold']  ** 2
Final_Data_Collection['Oil_2'] = Final_Data_Collection['Oil'] ** 2
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_3'] = Final_Data_Collection['Bitcoin_my_wallet_num_users']* Final_Data_Collection['Bitcoin_my_wallet_num_users'] * Final_Data_Collection['Bitcoin_my_wallet_num_users']
Final_Data_Collection['Volume_3'] = Final_Data_Collection['Volume'] * Final_Data_Collection['Volume'] * Final_Data_Collection['Volume']
Final_Data_Collection['Difficulty_3'] =Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty'] * Final_Data_Collection['Difficulty']
Final_Data_Collection['wallet_num_transaction_3'] = Final_Data_Collection['wallet_num_transaction']*Final_Data_Collection['wallet_num_transaction'] * Final_Data_Collection['wallet_num_transaction']
Final_Data_Collection['Bitcoin_Avg_Block_Size_3'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] *Final_Data_Collection['Bitcoin_Avg_Block_Size'] * Final_Data_Collection['Bitcoin_Avg_Block_Size']
Final_Data_Collection['Miners_Revenue_3'] = Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue'] * Final_Data_Collection['Miners_Revenue']
Final_Data_Collection['Hash_Rate_3'] = Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate'] * Final_Data_Collection['Hash_Rate']
Final_Data_Collection['Bitcoin_Cost_Transaction_3'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction'] * Final_Data_Collection['Bitcoin_Cost_Transaction']
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_3'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] * Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume']
Final_Data_Collection['Estimated_Transaction_Volume_3'] = Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume'] * Final_Data_Collection['Estimated_Transaction_Volume']
Final_Data_Collection['Total_Output_Volume_3'] = Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume'] * Final_Data_Collection['Total_Output_Volume']
Final_Data_Collection['num_transaction_per_Block_3'] = Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block'] * Final_Data_Collection['num_transaction_per_Block']
Final_Data_Collection['num_of_unique_addresses_3'] = Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses'] * Final_Data_Collection['num_of_unique_addresses']
Final_Data_Collection['num_of_transaction_3'] = Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction'] * Final_Data_Collection['num_of_transaction']
Final_Data_Collection['Total_transaction_fees_3'] = Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees'] * Final_Data_Collection['Total_transaction_fees']
Final_Data_Collection['Total_Bitcoins_3'] = Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins'] * Final_Data_Collection['Total_Bitcoins']
Final_Data_Collection['Median_transaction_confirmation_time_3'] = Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time'] * Final_Data_Collection['Median_transaction_confirmation_time']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['LT_Rate_3'] = Final_Data_Collection['LT_Rate'] ** 3
Final_Data_Collection['AAA_3'] = Final_Data_Collection['AAA'] ** 3
Final_Data_Collection['Gold_3'] = Final_Data_Collection['Gold']  ** 3
Final_Data_Collection['Oil_3'] = Final_Data_Collection['Oil'] ** 3
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_4'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] ** 4
Final_Data_Collection['Volume_4'] = Final_Data_Collection['Volume'] ** 4
Final_Data_Collection['Difficulty_4'] =Final_Data_Collection['Difficulty'] ** 4
Final_Data_Collection['wallet_num_transaction_4'] = Final_Data_Collection['wallet_num_transaction'] ** 4
Final_Data_Collection['Bitcoin_Avg_Block_Size_4'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] ** 4
Final_Data_Collection['Miners_Revenue_4'] = Final_Data_Collection['Miners_Revenue'] ** 4
Final_Data_Collection['Hash_Rate_4'] = Final_Data_Collection['Hash_Rate'] ** 4
Final_Data_Collection['Bitcoin_Cost_Transaction_4'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] ** 4
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_4'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] ** 4
Final_Data_Collection['Estimated_Transaction_Volume_4'] = Final_Data_Collection['Estimated_Transaction_Volume'] ** 4
Final_Data_Collection['Total_Output_Volume_4'] = Final_Data_Collection['Total_Output_Volume'] ** 4
Final_Data_Collection['num_transaction_per_Block_4'] = Final_Data_Collection['num_transaction_per_Block'] ** 4
Final_Data_Collection['num_of_unique_addresses_4'] = Final_Data_Collection['num_of_unique_addresses'] ** 4
Final_Data_Collection['num_of_transaction_4'] = Final_Data_Collection['num_of_transaction'] ** 4
Final_Data_Collection['Total_transaction_fees_4'] = Final_Data_Collection['Total_transaction_fees'] ** 4
Final_Data_Collection['Total_Bitcoins_4'] = Final_Data_Collection['Total_Bitcoins'] ** 4
Final_Data_Collection['Median_transaction_confirmation_time_4'] = Final_Data_Collection['Median_transaction_confirmation_time'] ** 4
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['LT_Rate_4'] = Final_Data_Collection['LT_Rate'] ** 4
Final_Data_Collection['AAA_4'] = Final_Data_Collection['AAA'] ** 4
Final_Data_Collection['Gold_4'] = Final_Data_Collection['Gold']  ** 4
Final_Data_Collection['Oil_4'] = Final_Data_Collection['Oil'] ** 4
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['Bitcoin_my_wallet_num_users_5'] = Final_Data_Collection['Bitcoin_my_wallet_num_users'] ** 5
Final_Data_Collection['Volume_5'] = Final_Data_Collection['Volume'] ** 5
Final_Data_Collection['Difficulty_5'] =Final_Data_Collection['Difficulty'] ** 5
Final_Data_Collection['wallet_num_transaction_5'] = Final_Data_Collection['wallet_num_transaction'] ** 5
Final_Data_Collection['Bitcoin_Avg_Block_Size_5'] = Final_Data_Collection['Bitcoin_Avg_Block_Size'] ** 5
Final_Data_Collection['Miners_Revenue_5'] = Final_Data_Collection['Miners_Revenue'] ** 5
Final_Data_Collection['Hash_Rate_5'] = Final_Data_Collection['Hash_Rate'] ** 5
Final_Data_Collection['Bitcoin_Cost_Transaction_5'] = Final_Data_Collection['Bitcoin_Cost_Transaction'] ** 5
Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume_5'] = Final_Data_Collection['Bitcoin_Cost_percentage_of_Transaction_Volume'] ** 5
Final_Data_Collection['Estimated_Transaction_Volume_5'] = Final_Data_Collection['Estimated_Transaction_Volume'] ** 5
Final_Data_Collection['Total_Output_Volume_5'] = Final_Data_Collection['Total_Output_Volume'] ** 5
Final_Data_Collection['num_transaction_per_Block_5'] = Final_Data_Collection['num_transaction_per_Block'] ** 5
Final_Data_Collection['num_of_unique_addresses_5'] = Final_Data_Collection['num_of_unique_addresses'] ** 5
Final_Data_Collection['num_of_transaction_5'] = Final_Data_Collection['num_of_transaction'] ** 5
Final_Data_Collection['Total_transaction_fees_5'] = Final_Data_Collection['Total_transaction_fees'] ** 5
Final_Data_Collection['Total_Bitcoins_5'] = Final_Data_Collection['Total_Bitcoins'] ** 5
Final_Data_Collection['Median_transaction_confirmation_time_5'] = Final_Data_Collection['Median_transaction_confirmation_time'] ** 5
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['LT_Rate_5'] = Final_Data_Collection['LT_Rate'] ** 5
Final_Data_Collection['AAA_5'] = Final_Data_Collection['AAA'] ** 5
Final_Data_Collection['Gold_5'] = Final_Data_Collection['Gold']  ** 5
Final_Data_Collection['Oil_5'] = Final_Data_Collection['Oil'] ** 5
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Final_Data_Collection['Class'] = Bitcoin_Price.loc[Date_vec_F,'Class']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_Data_Collection
# Out:
#             Bitcoin_my_wallet_num_users        Volume    Difficulty  \
# Date
# 2012-02-22                       2108.0  6.817477e+05  1.376302e+06
# 2012-02-23                       2159.0  5.101271e+05  1.376302e+06
# 2012-02-24                       2159.0  3.385065e+05  1.376302e+06
# 2012-02-27                       2253.0  2.698746e+05  1.376302e+06
# 2012-02-28                       2282.0  2.091140e+05  1.376302e+06
# ...                                 ...           ...           ...
# 2021-06-14                   74052123.0  4.964213e+08  1.993279e+13
# 2021-06-15                   74063489.0  7.734807e+08  1.993279e+13
# 2021-06-23                   74424320.0  1.181870e+09  1.993279e+13
# 2021-06-24                   74424320.0  5.678945e+08  1.993279e+13
# 2021-06-25                   74424320.0  3.467637e+08  1.993279e+13
#
#             wallet_num_transaction  Bitcoin_Avg_Block_Size  Miners_Revenue  \
# Date
# ...

# %%
Final_Data_Collection.to_csv('/Users/boxtim/Desktop/MFC Summer Project/Crypto MFC/FinalDataCollection_5_2c_more_feat.csv')

# %%
# Out:
# 2010
